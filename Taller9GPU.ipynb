# %%
pip install numba numpy
# Out:
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba) (0.43.0)

# %%
from gpu_rsa_toy_threads import run_experiment

# %%
run_experiment(
    n=100160063,
    use_gpu=True,
    threads_per_block=256
)
# Out:
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:696: NumbaPerformanceWarning: Grid size 40 will likely result in GPU under-utilization due to low occupancy.
#   warn(errors.NumbaPerformanceWarning(msg))
# ======================================================================
# Mode: gpu_threads
# ======================================================================
# n: 100160063
# Search interval: [2, 10007]
# GPU id: 0
# Threads per block: 256
# Blocks per grid: 40
# Total launched CUDA threads: 10240
# p: 10007
# q: 10009
# Verification p*q: 100160063
# Correct: True
# Elapsed time: 1.77489914 seconds
# (None,
#  FactorizationResult(mode='gpu_threads', n=100160063, p=10007, q=10009, search_start=2, search_end=10007, elapsed_seconds=1.7748991410001054, threads_per_block=256, blocks_per_grid=40, total_threads=10240, gpu_id=0))

# %%
run_experiment(
    n=1000036000099,
    compare=True,
    threads_per_block=256
)
# Out:
# ======================================================================
# Mode: cpu
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.08349897 seconds
#
# ======================================================================
# Mode: gpu_threads
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# GPU id: 0
# Threads per block: 256
# Blocks per grid: 3907
# Total launched CUDA threads: 1000192
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.00032816 seconds
#
# ======================================================================
# CPU vs GPU comparison
# ======================================================================
# n: 1000036000099
# CPU time: 0.08349897 seconds
# GPU time: 0.00032816 seconds
# Speedup CPU/GPU: 254.4451x
#
# Interpretation note:
# - For small n, GPU can be slower because CUDA startup and JIT overhead dominate.
# - For larger toy n, more CUDA threads do useful work and GPU may become beneficial.
# - This does not represent a practical attack against real RSA.
# (FactorizationResult(mode='cpu', n=1000036000099, p=1000003, q=1000033, search_start=2, search_end=1000017, elapsed_seconds=0.08349897300013254, threads_per_block=None, blocks_per_grid=None, total_threads=None, gpu_id=None),
#  FactorizationResult(mode='gpu_threads', n=1000036000099, p=1000003, q=1000033, search_start=2, search_end=1000017, elapsed_seconds=0.00032816099997035053, threads_per_block=256, blocks_per_grid=3907, total_threads=1000192, gpu_id=0))

# %%
run_experiment(
    n=1000036000099,
    compare=True,
    threads_per_block=128
)

run_experiment(
    n=1000036000099,
    compare=True,
    threads_per_block=256
)

run_experiment(
    n=1000036000099,
    compare=True,
    threads_per_block=512
)
# Out:
# ======================================================================
# Mode: cpu
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.07790331 seconds
#
# ======================================================================
# Mode: gpu_threads
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# GPU id: 0
# Threads per block: 128
# Blocks per grid: 7813
# Total launched CUDA threads: 1000064
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.00037551 seconds
#
# ======================================================================
# CPU vs GPU comparison
# ======================================================================
# n: 1000036000099
# CPU time: 0.07790331 seconds
# GPU time: 0.00037551 seconds
# Speedup CPU/GPU: 207.4617x
#
# Interpretation note:
# - For small n, GPU can be slower because CUDA startup and JIT overhead dominate.
# - For larger toy n, more CUDA threads do useful work and GPU may become beneficial.
# - This does not represent a practical attack against real RSA.
#
# ======================================================================
# Mode: cpu
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.07857356 seconds
#
# ======================================================================
# Mode: gpu_threads
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# GPU id: 0
# Threads per block: 256
# Blocks per grid: 3907
# Total launched CUDA threads: 1000192
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.00025100 seconds
#
# ======================================================================
# CPU vs GPU comparison
# ======================================================================
# n: 1000036000099
# CPU time: 0.07857356 seconds
# GPU time: 0.00025100 seconds
# Speedup CPU/GPU: 313.0471x
#
# Interpretation note:
# - For small n, GPU can be slower because CUDA startup and JIT overhead dominate.
# - For larger toy n, more CUDA threads do useful work and GPU may become beneficial.
# - This does not represent a practical attack against real RSA.
#
# ======================================================================
# Mode: cpu
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.07487655 seconds
#
# ======================================================================
# Mode: gpu_threads
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# GPU id: 0
# Threads per block: 512
# Blocks per grid: 1954
# Total launched CUDA threads: 1000448
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.00025475 seconds
#
# ======================================================================
# CPU vs GPU comparison
# ======================================================================
# n: 1000036000099
# CPU time: 0.07487655 seconds
# GPU time: 0.00025475 seconds
# Speedup CPU/GPU: 293.9240x
#
# Interpretation note:
# - For small n, GPU can be slower because CUDA startup and JIT overhead dominate.
# - For larger toy n, more CUDA threads do useful work and GPU may become beneficial.
# - This does not represent a practical attack against real RSA.
# (FactorizationResult(mode='cpu', n=1000036000099, p=1000003, q=1000033, search_start=2, search_end=1000017, elapsed_seconds=0.07487654900000962, threads_per_block=None, blocks_per_grid=None, total_threads=None, gpu_id=None),
#  FactorizationResult(mode='gpu_threads', n=1000036000099, p=1000003, q=1000033, search_start=2, search_end=1000017, elapsed_seconds=0.00025474799986113794, threads_per_block=512, blocks_per_grid=1954, total_threads=1000448, gpu_id=0))

# %%
 run_experiment (
 n =100160063 ,
 compare = True ,
 threads_per_block =256
 )

 run_experiment (
 n =10002200057 ,
 compare = True ,
 threads_per_block =256
 )

 run_experiment (
 n =1000036000099 ,
 compare = True ,
 threads_per_block =256
 )
# Out:
# ======================================================================
# Mode: cpu
# ======================================================================
# n: 100160063
# Search interval: [2, 10007]
# p: 10007
# q: 10009
# Verification p*q: 100160063
# Correct: True
# Elapsed time: 0.00102675 seconds
#
# ======================================================================
# Mode: gpu_threads
# ======================================================================
# n: 100160063
# Search interval: [2, 10007]
# GPU id: 0
# Threads per block: 256
# Blocks per grid: 40
# Total launched CUDA threads: 10240
# p: 10007
# q: 10009
# Verification p*q: 100160063
# Correct: True
# Elapsed time: 0.00027755 seconds
#
# ======================================================================
# CPU vs GPU comparison
# ======================================================================
# n: 100160063
# CPU time: 0.00102675 seconds
# GPU time: 0.00027755 seconds
# Speedup CPU/GPU: 3.6993x
#
# Interpretation note:
# - For small n, GPU can be slower because CUDA startup and JIT overhead dominate.
# - For larger toy n, more CUDA threads do useful work and GPU may become beneficial.
# - This does not represent a practical attack against real RSA.
#
# ======================================================================
# Mode: cpu
# ======================================================================
# n: 10002200057
# Search interval: [2, 100010]
# p: 100003
# q: 100019
# Verification p*q: 10002200057
# Correct: True
# Elapsed time: 0.01397323 seconds
#
# ======================================================================
# Mode: gpu_threads
# ======================================================================
# n: 10002200057
# Search interval: [2, 100010]
# GPU id: 0
# Threads per block: 256
# Blocks per grid: 391
# Total launched CUDA threads: 100096
# p: 100003
# q: 100019
# Verification p*q: 10002200057
# Correct: True
# Elapsed time: 0.00026944 seconds
#
# ======================================================================
# CPU vs GPU comparison
# ======================================================================
# n: 10002200057
# CPU time: 0.01397323 seconds
# GPU time: 0.00026944 seconds
# Speedup CPU/GPU: 51.8603x
#
# Interpretation note:
# - For small n, GPU can be slower because CUDA startup and JIT overhead dominate.
# - For larger toy n, more CUDA threads do useful work and GPU may become beneficial.
# - This does not represent a practical attack against real RSA.
#
# ======================================================================
# Mode: cpu
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.13770074 seconds
#
# ======================================================================
# Mode: gpu_threads
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# GPU id: 0
# Threads per block: 256
# Blocks per grid: 3907
# Total launched CUDA threads: 1000192
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.00032442 seconds
#
# ======================================================================
# CPU vs GPU comparison
# ======================================================================
# n: 1000036000099
# CPU time: 0.13770074 seconds
# GPU time: 0.00032442 seconds
# Speedup CPU/GPU: 424.4547x
#
# Interpretation note:
# - For small n, GPU can be slower because CUDA startup and JIT overhead dominate.
# - For larger toy n, more CUDA threads do useful work and GPU may become beneficial.
# - This does not represent a practical attack against real RSA.
# (FactorizationResult(mode='cpu', n=1000036000099, p=1000003, q=1000033, search_start=2, search_end=1000017, elapsed_seconds=0.13770073700015928, threads_per_block=None, blocks_per_grid=None, total_threads=None, gpu_id=None),
#  FactorizationResult(mode='gpu_threads', n=1000036000099, p=1000003, q=1000033, search_start=2, search_end=1000017, elapsed_seconds=0.0003244179999910557, threads_per_block=256, blocks_per_grid=3907, total_threads=1000192, gpu_id=0))

# %%
run_experiment (
n =1000036000099 ,
compare = True ,
threads_per_block =128
)

run_experiment (
n =1000036000099 ,
compare = True ,
threads_per_block =256
)

run_experiment (
n =1000036000099 ,
compare = True ,
threads_per_block =512
)
# Out:
# ======================================================================
# Mode: cpu
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.07711791 seconds
#
# ======================================================================
# Mode: gpu_threads
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# GPU id: 0
# Threads per block: 128
# Blocks per grid: 7813
# Total launched CUDA threads: 1000064
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.00041579 seconds
#
# ======================================================================
# CPU vs GPU comparison
# ======================================================================
# n: 1000036000099
# CPU time: 0.07711791 seconds
# GPU time: 0.00041579 seconds
# Speedup CPU/GPU: 185.4714x
#
# Interpretation note:
# - For small n, GPU can be slower because CUDA startup and JIT overhead dominate.
# - For larger toy n, more CUDA threads do useful work and GPU may become beneficial.
# - This does not represent a practical attack against real RSA.
#
# ======================================================================
# Mode: cpu
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.07449056 seconds
#
# ======================================================================
# Mode: gpu_threads
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# GPU id: 0
# Threads per block: 256
# Blocks per grid: 3907
# Total launched CUDA threads: 1000192
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.00022278 seconds
#
# ======================================================================
# CPU vs GPU comparison
# ======================================================================
# n: 1000036000099
# CPU time: 0.07449056 seconds
# GPU time: 0.00022278 seconds
# Speedup CPU/GPU: 334.3728x
#
# Interpretation note:
# - For small n, GPU can be slower because CUDA startup and JIT overhead dominate.
# - For larger toy n, more CUDA threads do useful work and GPU may become beneficial.
# - This does not represent a practical attack against real RSA.
#
# ======================================================================
# Mode: cpu
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.07397999 seconds
#
# ======================================================================
# Mode: gpu_threads
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# GPU id: 0
# Threads per block: 512
# Blocks per grid: 1954
# Total launched CUDA threads: 1000448
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.00022825 seconds
#
# ======================================================================
# CPU vs GPU comparison
# ======================================================================
# n: 1000036000099
# CPU time: 0.07397999 seconds
# GPU time: 0.00022825 seconds
# Speedup CPU/GPU: 324.1239x
#
# Interpretation note:
# - For small n, GPU can be slower because CUDA startup and JIT overhead dominate.
# - For larger toy n, more CUDA threads do useful work and GPU may become beneficial.
# - This does not represent a practical attack against real RSA.
# (FactorizationResult(mode='cpu', n=1000036000099, p=1000003, q=1000033, search_start=2, search_end=1000017, elapsed_seconds=0.07397999099998742, threads_per_block=None, blocks_per_grid=None, total_threads=None, gpu_id=None),
#  FactorizationResult(mode='gpu_threads', n=1000036000099, p=1000003, q=1000033, search_start=2, search_end=1000017, elapsed_seconds=0.00022824600000603823, threads_per_block=512, blocks_per_grid=1954, total_threads=1000448, gpu_id=0))
