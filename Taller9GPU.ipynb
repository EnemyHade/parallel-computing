# %%
pip install numba numpy
# Out:
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba) (0.43.0)

# %%
from gpu_rsa_toy_threads import run_experiment

# %%
run_experiment(
    n=100160063,
    use_gpu=True,
    threads_per_block=256
)
# Out:
# ======================================================================
# Mode: gpu_threads
# ======================================================================
# n: 100160063
# Search interval: [2, 10007]
# GPU id: 0
# Threads per block: 256
# Blocks per grid: 40
# Total launched CUDA threads: 10240
# p: 10007
# q: 10009
# Verification p*q: 100160063
# Correct: True
# Elapsed time: 0.11061190 seconds
# C:\Users\asus\.conda\envs\INCENDIOS_FLOW\Lib\site-packages\numba\cuda\dispatcher.py:536: NumbaPerformanceWarning: Grid size 40 will likely result in GPU under-utilization due to low occupancy.
#   warn(NumbaPerformanceWarning(msg))
# (None,
#  FactorizationResult(mode='gpu_threads', n=100160063, p=10007, q=10009, search_start=2, search_end=10007, elapsed_seconds=0.11061189998872578, threads_per_block=256, blocks_per_grid=40, total_threads=10240, gpu_id=0))

# %%
run_experiment(
    n=1000036000099,
    compare=True,
    threads_per_block=256
)
# Out:
# ======================================================================
# Mode: cpu
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.07797070 seconds
#
# ======================================================================
# Mode: gpu_threads
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# GPU id: 0
# Threads per block: 256
# Blocks per grid: 3907
# Total launched CUDA threads: 1000192
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.00069130 seconds
#
# ======================================================================
# CPU vs GPU comparison
# ======================================================================
# n: 1000036000099
# CPU time: 0.07797070 seconds
# GPU time: 0.00069130 seconds
# Speedup CPU/GPU: 112.7885x
#
# Interpretation note:
# - For small n, GPU can be slower because CUDA startup and JIT overhead dominate.
# - For larger toy n, more CUDA threads do useful work and GPU may become beneficial.
# - This does not represent a practical attack against real RSA.
# (FactorizationResult(mode='cpu', n=1000036000099, p=1000003, q=1000033, search_start=2, search_end=1000017, elapsed_seconds=0.07797069998923689, threads_per_block=None, blocks_per_grid=None, total_threads=None, gpu_id=None),
#  FactorizationResult(mode='gpu_threads', n=1000036000099, p=1000003, q=1000033, search_start=2, search_end=1000017, elapsed_seconds=0.0006913000252097845, threads_per_block=256, blocks_per_grid=3907, total_threads=1000192, gpu_id=0))

# %%
run_experiment(
    n=1000036000099,
    compare=True,
    threads_per_block=128
)

run_experiment(
    n=1000036000099,
    compare=True,
    threads_per_block=256
)

run_experiment(
    n=1000036000099,
    compare=True,
    threads_per_block=512
)
# Out:
# ======================================================================
# Mode: cpu
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.05563970 seconds
#
# ======================================================================
# Mode: gpu_threads
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# GPU id: 0
# Threads per block: 128
# Blocks per grid: 7813
# Total launched CUDA threads: 1000064
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.00259620 seconds
#
# ======================================================================
# CPU vs GPU comparison
# ======================================================================
# n: 1000036000099
# CPU time: 0.05563970 seconds
# GPU time: 0.00259620 seconds
# Speedup CPU/GPU: 21.4312x
#
# Interpretation note:
# - For small n, GPU can be slower because CUDA startup and JIT overhead dominate.
# - For larger toy n, more CUDA threads do useful work and GPU may become beneficial.
# - This does not represent a practical attack against real RSA.
#
# ======================================================================
# Mode: cpu
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.05437140 seconds
#
# ======================================================================
# Mode: gpu_threads
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# GPU id: 0
# Threads per block: 256
# Blocks per grid: 3907
# Total launched CUDA threads: 1000192
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.00140710 seconds
#
# ======================================================================
# CPU vs GPU comparison
# ======================================================================
# n: 1000036000099
# CPU time: 0.05437140 seconds
# GPU time: 0.00140710 seconds
# Speedup CPU/GPU: 38.6408x
#
# Interpretation note:
# - For small n, GPU can be slower because CUDA startup and JIT overhead dominate.
# - For larger toy n, more CUDA threads do useful work and GPU may become beneficial.
# - This does not represent a practical attack against real RSA.
#
# ======================================================================
# Mode: cpu
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.07231790 seconds
#
# ======================================================================
# Mode: gpu_threads
# ======================================================================
# n: 1000036000099
# Search interval: [2, 1000017]
# GPU id: 0
# Threads per block: 512
# Blocks per grid: 1954
# Total launched CUDA threads: 1000448
# p: 1000003
# q: 1000033
# Verification p*q: 1000036000099
# Correct: True
# Elapsed time: 0.00062280 seconds
#
# ======================================================================
# CPU vs GPU comparison
# ======================================================================
# n: 1000036000099
# CPU time: 0.07231790 seconds
# GPU time: 0.00062280 seconds
# Speedup CPU/GPU: 116.1174x
#
# Interpretation note:
# - For small n, GPU can be slower because CUDA startup and JIT overhead dominate.
# - For larger toy n, more CUDA threads do useful work and GPU may become beneficial.
# - This does not represent a practical attack against real RSA.
# (FactorizationResult(mode='cpu', n=1000036000099, p=1000003, q=1000033, search_start=2, search_end=1000017, elapsed_seconds=0.07231790001969784, threads_per_block=None, blocks_per_grid=None, total_threads=None, gpu_id=None),
#  FactorizationResult(mode='gpu_threads', n=1000036000099, p=1000003, q=1000033, search_start=2, search_end=1000017, elapsed_seconds=0.0006228000856935978, threads_per_block=512, blocks_per_grid=1954, total_threads=1000448, gpu_id=0))
